# %%
#导入相关的库
import paddle
from paddle.nn import Linear
import paddle.nn.functional as F
import numpy as np
import os
import random
import matplotlib.pyplot as plt



# 编写加载数据的函数
def load_data():
    datafile='./data/housing.data'
    data=np.fromfile(datafile,sep=' ',dtype=np.float32)
    #读取数据文件
    feature_names = [ 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',                       'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV' ]
    feature_num = len(feature_names)
    data = data.reshape([data.shape[0] // feature_num, feature_num])
    #将一维的数据转成二维
    ratio=0.8
    #设置训练集的比例为0.8
    offset=int(data.shape[0]*ratio)
    training_data=data[:offset]
    #对数据进行标准化
    maximums,minimums,avgs=training_data.max(axis=0),training_data.min(axis=0),training_data.sum(axis=0)/training_data.shape[0]
    global max_values
    global min_values
    global avg_values
    max_values=maximums
    min_values=minimums
    avg_values=avgs
    for i in range(feature_num):
        data[:,i]=(data[:,i]-avgs[i])/(maximums[i]-minimums[i])
    training_data=data[:offset]
    test_data=data[offset:]
    return training_data,test_data



# 定义网络结构为两层，全连接层+激活函数+全连接层
class Net(paddle.nn.Layer):
    def __init__(self):
        super(Net,self).__init__()

        self.fc1=Linear(in_features=13,out_features=128)
        self.fc2=Linear(in_features=128,out_features=1)
    def forward(self,inputs):
        x=self.fc1(inputs)
        x=F.relu(x)
        x=self.fc2(x)
        return x

#创建网络的一个对象
model=Net()
model.train()
#进入模型的训练模式
training_data, test_data = load_data()
opt = paddle.optimizer.Adadelta(learning_rate=0.01, parameters=model.parameters())
#设置优化器为Adadelta


EPOCH_NUM = 100   #设置迭代次数
BATCH_SIZE = 10  #设置批次大小

# 定义外层循环
losses=[]
for epoch_id in range(1,EPOCH_NUM+1):
    # 在每轮迭代开始之前，将训练数据的顺序随机的打乱
    np.random.shuffle(training_data)
    # 将训练数据进行拆分，每个batch包含10条数据
    mini_batches = [training_data[k:k+BATCH_SIZE] for k in range(0, len(training_data), BATCH_SIZE)]
    # 定义内层循环
    for iter_id, mini_batch in enumerate(mini_batches):
        x = np.array(mini_batch[:, :-1]) # 获得当前批次训练数据
        y = np.array(mini_batch[:, -1:]) # 获得当前批次训练标签（真实房价）
        # 将numpy数据转为飞桨动态图tensor形式
        house_features = paddle.to_tensor(x)
        prices = paddle.to_tensor(y)

        # 前向计算
        predicts = model(house_features)

        # 计算损失
        loss = F.square_error_cost(predicts, label=prices)
        avg_loss = paddle.mean(loss)
        losses.append(avg_loss.numpy())
        if iter_id%20==0:
            print("epoch: {}, iter: {}, loss is: {}".format(epoch_id, iter_id, avg_loss.numpy()))

        # 反向传播
        avg_loss.backward()
        # 最小化loss,更新参数
        opt.step()
        # 清除梯度
        opt.clear_grad()



plot_x = np.arange(len(losses))
plot_y = np.array(losses)
plt.plot(plot_x, plot_y)
plt.show()



def load_one_example():
    # 从上边已加载的测试集中，随机选择一条作为测试数据
    idx = np.random.randint(0, test_data.shape[0])
    one_data, label = test_data[idx, :-1], test_data[idx, -1]
    # 修改该条数据shape为[1,13]
    one_data =  one_data.reshape([1,-1])

    return one_data, label



# 保存模型参数，文件名为LR_model.pdparams
paddle.save(model.state_dict(), 'LR_model.pdparams')
print("模型保存成功，模型参数保存在LR_model.pdparams中")


# 参数为保存模型参数的文件地址
model_dict = paddle.load('LR_model.pdparams')
model.load_dict(model_dict)
model.eval()

# 参数为数据集的文件地址
one_data, label = load_one_example()
# 将数据转为动态图的variable格式 
one_data = paddle.to_tensor(one_data)
predict = model(one_data)

# 对结果做反归一化处理
predict = predict * (max_values[-1] - min_values[-1]) + avg_values[-1]
# 对label数据做反归一化处理
label = label * (max_values[-1] - min_values[-1]) + avg_values[-1]

print("Inference result is {}, the corresponding label is {}".format(predict.numpy(), label))
# Out:
# epoch: 1, iter: 0, loss is: [0.0777044]
# epoch: 1, iter: 20, loss is: [0.00827091]
# epoch: 1, iter: 40, loss is: [0.01498856]
# epoch: 2, iter: 0, loss is: [0.00422252]
# epoch: 2, iter: 20, loss is: [0.00556734]
# epoch: 2, iter: 40, loss is: [0.00486926]
# epoch: 3, iter: 0, loss is: [0.00377865]
# epoch: 3, iter: 20, loss is: [0.01206368]
# epoch: 3, iter: 40, loss is: [0.00310414]
# epoch: 4, iter: 0, loss is: [0.00161597]
# epoch: 4, iter: 20, loss is: [0.0056264]
# epoch: 4, iter: 40, loss is: [0.00713236]
# epoch: 5, iter: 0, loss is: [0.03340415]
# epoch: 5, iter: 20, loss is: [0.00413197]
# epoch: 5, iter: 40, loss is: [0.00455936]
# epoch: 6, iter: 0, loss is: [0.00233922]
# epoch: 6, iter: 20, loss is: [0.00797919]
# epoch: 6, iter: 40, loss is: [0.00366413]
# epoch: 7, iter: 0, loss is: [0.00267748]
# epoch: 7, iter: 20, loss is: [0.00196597]
# epoch: 7, iter: 40, loss is: [0.00109943]
# epoch: 8, iter: 0, loss is: [0.00793964]
# epoch: 8, iter: 20, loss is: [0.00311199]
# epoch: 8, iter: 40, loss is: [0.00073312]
# epoch: 9, iter: 0, loss is: [0.01449305]
# epoch: 9, iter: 20, loss is: [0.00235446]
# epoch: 9, iter: 40, loss is: [0.00060117]
# epoch: 10, iter: 0, loss is: [0.00771201]
# epoch: 10, iter: 20, loss is: [0.00329241]
# epoch: 10, iter: 40, loss is: [0.00185021]
# epoch: 11, iter: 0, loss is: [0.00236168]
# epoch: 11, iter: 20, loss is: [0.00156007]
# epoch: 11, iter: 40, loss is: [0.00273302]
# epoch: 12, iter: 0, loss is: [0.00424902]
# epoch: 12, iter: 20, loss is: [0.001864]
# epoch: 12, iter: 40, loss is: [0.00419259]
# epoch: 13, iter: 0, loss is: [0.00343321]
# epoch: 13, iter: 20, loss is: [0.00391779]
# epoch: 13, iter: 40, loss is: [0.00149222]
# epoch: 14, iter: 0, loss is: [0.00211594]
# epoch: 14, iter: 20, loss is: [0.00104812]
# epoch: 14, iter: 40, loss is: [0.00054138]
# epoch: 15, iter: 0, loss is: [0.00398151]
# epoch: 15, iter: 20, loss is: [0.00299547]
# epoch: 15, iter: 40, loss is: [0.00345081]
# epoch: 16, iter: 0, loss is: [0.00617713]
# epoch: 16, iter: 20, loss is: [0.01172568]
# epoch: 16, iter: 40, loss is: [0.0015655]
# epoch: 17, iter: 0, loss is: [0.00266299]
# epoch: 17, iter: 20, loss is: [0.00936018]
# epoch: 17, iter: 40, loss is: [0.02069326]
# epoch: 18, iter: 0, loss is: [0.0102576]
# epoch: 18, iter: 20, loss is: [0.00245012]
# epoch: 18, iter: 40, loss is: [0.00710166]
# epoch: 19, iter: 0, loss is: [0.0026245]
# epoch: 19, iter: 20, loss is: [0.00185389]
# epoch: 19, iter: 40, loss is: [0.00047587]
# epoch: 20, iter: 0, loss is: [0.00826039]
# epoch: 20, iter: 20, loss is: [0.00232079]
# epoch: 20, iter: 40, loss is: [0.00428644]
# epoch: 21, iter: 0, loss is: [0.02946241]
# epoch: 21, iter: 20, loss is: [0.00496055]
# epoch: 21, iter: 40, loss is: [0.00372624]
# epoch: 22, iter: 0, loss is: [0.00092828]
# epoch: 22, iter: 20, loss is: [0.0169525]
# epoch: 22, iter: 40, loss is: [0.00151478]
# epoch: 23, iter: 0, loss is: [0.00458005]
# epoch: 23, iter: 20, loss is: [0.00341774]
# epoch: 23, iter: 40, loss is: [0.00333034]
# epoch: 24, iter: 0, loss is: [0.00350544]
# epoch: 24, iter: 20, loss is: [0.00276438]
# epoch: 24, iter: 40, loss is: [0.00601127]
# epoch: 25, iter: 0, loss is: [0.00729251]
# epoch: 25, iter: 20, loss is: [0.00170601]
# epoch: 25, iter: 40, loss is: [0.00242131]
# epoch: 26, iter: 0, loss is: [0.00101143]
# epoch: 26, iter: 20, loss is: [0.00187949]
# epoch: 26, iter: 40, loss is: [0.00099679]
# epoch: 27, iter: 0, loss is: [0.00172443]
# epoch: 27, iter: 20, loss is: [0.00228608]
# epoch: 27, iter: 40, loss is: [0.00217989]
# epoch: 28, iter: 0, loss is: [0.00417769]
# epoch: 28, iter: 20, loss is: [0.00090325]
# epoch: 28, iter: 40, loss is: [0.00034801]
# epoch: 29, iter: 0, loss is: [0.00148342]
# epoch: 29, iter: 20, loss is: [0.00214058]
# epoch: 29, iter: 40, loss is: [0.00393068]
# epoch: 30, iter: 0, loss is: [0.00189568]
# epoch: 30, iter: 20, loss is: [0.00199816]
# epoch: 30, iter: 40, loss is: [0.00197118]
# epoch: 31, iter: 0, loss is: [0.00150105]
# epoch: 31, iter: 20, loss is: [0.00970499]
# epoch: 31, iter: 40, loss is: [0.00070338]
# epoch: 32, iter: 0, loss is: [0.00102236]
# epoch: 32, iter: 20, loss is: [0.00201524]
# epoch: 32, iter: 40, loss is: [0.00013508]
# epoch: 33, iter: 0, loss is: [0.01345577]
# epoch: 33, iter: 20, loss is: [0.00075429]
# epoch: 33, iter: 40, loss is: [0.00067417]
# epoch: 34, iter: 0, loss is: [0.00264035]
# epoch: 34, iter: 20, loss is: [0.00255058]
# epoch: 34, iter: 40, loss is: [0.01940644]
# epoch: 35, iter: 0, loss is: [0.00457088]
# epoch: 35, iter: 20, loss is: [0.0016894]
# epoch: 35, iter: 40, loss is: [0.00033157]
# epoch: 36, iter: 0, loss is: [0.00185651]
# epoch: 36, iter: 20, loss is: [0.00091179]
# epoch: 36, iter: 40, loss is: [0.0006882]
# epoch: 37, iter: 0, loss is: [0.0009067]
# epoch: 37, iter: 20, loss is: [0.00218333]
# epoch: 37, iter: 40, loss is: [0.00278833]
# epoch: 38, iter: 0, loss is: [0.00146324]
# epoch: 38, iter: 20, loss is: [0.0010795]
# epoch: 38, iter: 40, loss is: [0.00440007]
# epoch: 39, iter: 0, loss is: [0.00201393]
# epoch: 39, iter: 20, loss is: [0.00078389]
# epoch: 39, iter: 40, loss is: [0.00386655]
# epoch: 40, iter: 0, loss is: [0.00472444]
# epoch: 40, iter: 20, loss is: [0.00476606]
# epoch: 40, iter: 40, loss is: [0.0008469]
# epoch: 41, iter: 0, loss is: [0.00613606]
# epoch: 41, iter: 20, loss is: [0.00233773]
# epoch: 41, iter: 40, loss is: [0.00147168]
# epoch: 42, iter: 0, loss is: [0.00767615]
# epoch: 42, iter: 20, loss is: [0.00072267]
# epoch: 42, iter: 40, loss is: [0.00021293]
# epoch: 43, iter: 0, loss is: [0.00305811]
# epoch: 43, iter: 20, loss is: [0.00177806]
# epoch: 43, iter: 40, loss is: [0.00091341]
# epoch: 44, iter: 0, loss is: [0.00240452]
# epoch: 44, iter: 20, loss is: [0.00230492]
# epoch: 44, iter: 40, loss is: [0.00460645]
# epoch: 45, iter: 0, loss is: [0.0027453]
# epoch: 45, iter: 20, loss is: [0.00037367]
# epoch: 45, iter: 40, loss is: [0.00374883]
# epoch: 46, iter: 0, loss is: [0.00357081]
# epoch: 46, iter: 20, loss is: [0.00080488]
# epoch: 46, iter: 40, loss is: [0.00230945]
# epoch: 47, iter: 0, loss is: [0.00362825]
# epoch: 47, iter: 20, loss is: [0.00178873]
# epoch: 47, iter: 40, loss is: [0.00139759]
# epoch: 48, iter: 0, loss is: [0.00090323]
# epoch: 48, iter: 20, loss is: [0.000794]
# epoch: 48, iter: 40, loss is: [0.00040465]
# epoch: 49, iter: 0, loss is: [0.00089241]
# epoch: 49, iter: 20, loss is: [0.00778352]
# epoch: 49, iter: 40, loss is: [0.00088625]
# epoch: 50, iter: 0, loss is: [0.00070445]
# epoch: 50, iter: 20, loss is: [0.00076563]
# epoch: 50, iter: 40, loss is: [0.00179526]
# epoch: 51, iter: 0, loss is: [0.0017801]
# epoch: 51, iter: 20, loss is: [0.00096141]
# epoch: 51, iter: 40, loss is: [0.02457474]
# epoch: 52, iter: 0, loss is: [0.01783791]
# epoch: 52, iter: 20, loss is: [0.00151328]
# epoch: 52, iter: 40, loss is: [0.00395325]
# epoch: 53, iter: 0, loss is: [0.00303558]
# epoch: 53, iter: 20, loss is: [0.00082229]
# epoch: 53, iter: 40, loss is: [0.00222154]
# epoch: 54, iter: 0, loss is: [0.00262791]
# epoch: 54, iter: 20, loss is: [0.00251752]
# epoch: 54, iter: 40, loss is: [0.01657123]
# epoch: 55, iter: 0, loss is: [0.01526985]
# epoch: 55, iter: 20, loss is: [0.00347453]
# epoch: 55, iter: 40, loss is: [0.00371947]
# epoch: 56, iter: 0, loss is: [0.00098036]
# epoch: 56, iter: 20, loss is: [0.00062179]
# epoch: 56, iter: 40, loss is: [0.00143805]
# epoch: 57, iter: 0, loss is: [0.00176903]
# epoch: 57, iter: 20, loss is: [0.00354835]
# epoch: 57, iter: 40, loss is: [0.00046561]
# epoch: 58, iter: 0, loss is: [0.00368496]
# epoch: 58, iter: 20, loss is: [0.0071375]
# epoch: 58, iter: 40, loss is: [0.00015228]
# epoch: 59, iter: 0, loss is: [0.00172354]
# epoch: 59, iter: 20, loss is: [0.00513723]
# epoch: 59, iter: 40, loss is: [0.00041685]
# epoch: 60, iter: 0, loss is: [0.00082337]
# epoch: 60, iter: 20, loss is: [0.0009167]
# epoch: 60, iter: 40, loss is: [0.00226866]
# epoch: 61, iter: 0, loss is: [0.00108037]
# epoch: 61, iter: 20, loss is: [0.00117746]
# epoch: 61, iter: 40, loss is: [0.0002049]
# epoch: 62, iter: 0, loss is: [0.00148986]
# epoch: 62, iter: 20, loss is: [0.0012314]
# epoch: 62, iter: 40, loss is: [0.00039923]
# epoch: 63, iter: 0, loss is: [0.00493922]
# epoch: 63, iter: 20, loss is: [0.00064767]
# epoch: 63, iter: 40, loss is: [0.00099548]
# epoch: 64, iter: 0, loss is: [0.00120633]
# epoch: 64, iter: 20, loss is: [0.00238462]
# epoch: 64, iter: 40, loss is: [0.0005255]
# epoch: 65, iter: 0, loss is: [0.01140055]
# epoch: 65, iter: 20, loss is: [0.00098318]
# epoch: 65, iter: 40, loss is: [0.00055666]
# epoch: 66, iter: 0, loss is: [0.00127303]
# epoch: 66, iter: 20, loss is: [0.00282876]
# epoch: 66, iter: 40, loss is: [0.00039646]
# epoch: 67, iter: 0, loss is: [0.002321]
# epoch: 67, iter: 20, loss is: [0.00042992]
# epoch: 67, iter: 40, loss is: [0.00089223]
# epoch: 68, iter: 0, loss is: [0.00273765]
# epoch: 68, iter: 20, loss is: [0.00110818]
# epoch: 68, iter: 40, loss is: [0.001459]
# epoch: 69, iter: 0, loss is: [0.00354607]
# epoch: 69, iter: 20, loss is: [0.00067397]
# epoch: 69, iter: 40, loss is: [0.00196068]
# epoch: 70, iter: 0, loss is: [0.00145882]
# epoch: 70, iter: 20, loss is: [0.00121101]
# epoch: 70, iter: 40, loss is: [0.00346255]
# epoch: 71, iter: 0, loss is: [0.00210331]
# epoch: 71, iter: 20, loss is: [0.00195102]
# epoch: 71, iter: 40, loss is: [0.0016698]
# epoch: 72, iter: 0, loss is: [0.00165554]
# epoch: 72, iter: 20, loss is: [0.00101835]
# epoch: 72, iter: 40, loss is: [0.00370923]
# epoch: 73, iter: 0, loss is: [0.00376734]
# epoch: 73, iter: 20, loss is: [0.0027388]
# epoch: 73, iter: 40, loss is: [0.00297352]
# epoch: 74, iter: 0, loss is: [0.00365183]
# epoch: 74, iter: 20, loss is: [0.0006568]
# epoch: 74, iter: 40, loss is: [0.00019794]
# epoch: 75, iter: 0, loss is: [0.00109172]
# epoch: 75, iter: 20, loss is: [0.00205352]
# epoch: 75, iter: 40, loss is: [0.00068067]
# epoch: 76, iter: 0, loss is: [0.00042746]
# epoch: 76, iter: 20, loss is: [0.00124125]
# epoch: 76, iter: 40, loss is: [0.00074194]
# epoch: 77, iter: 0, loss is: [0.00125309]
# epoch: 77, iter: 20, loss is: [0.00095799]
# epoch: 77, iter: 40, loss is: [0.00056104]
# epoch: 78, iter: 0, loss is: [0.00185863]
# epoch: 78, iter: 20, loss is: [0.00316668]
# epoch: 78, iter: 40, loss is: [0.00163769]
# epoch: 79, iter: 0, loss is: [0.00320716]
# epoch: 79, iter: 20, loss is: [0.00733388]
# epoch: 79, iter: 40, loss is: [0.00272231]
# epoch: 80, iter: 0, loss is: [0.00579437]
# epoch: 80, iter: 20, loss is: [0.00273143]
# epoch: 80, iter: 40, loss is: [0.00199008]
# epoch: 81, iter: 0, loss is: [0.00123046]
# epoch: 81, iter: 20, loss is: [0.00232174]
# epoch: 81, iter: 40, loss is: [0.00043531]
# epoch: 82, iter: 0, loss is: [0.00075356]
# epoch: 82, iter: 20, loss is: [0.00104875]
# epoch: 82, iter: 40, loss is: [0.00096876]
# epoch: 83, iter: 0, loss is: [0.00085107]
# epoch: 83, iter: 20, loss is: [0.00126471]
# epoch: 83, iter: 40, loss is: [0.00074671]
# epoch: 84, iter: 0, loss is: [0.00296883]
# epoch: 84, iter: 20, loss is: [0.00150371]
# epoch: 84, iter: 40, loss is: [0.00302642]
# epoch: 85, iter: 0, loss is: [0.00283192]
# epoch: 85, iter: 20, loss is: [0.00024967]
# epoch: 85, iter: 40, loss is: [0.00122353]
# epoch: 86, iter: 0, loss is: [0.00143494]
# epoch: 86, iter: 20, loss is: [0.00273986]
# epoch: 86, iter: 40, loss is: [0.00049716]
# epoch: 87, iter: 0, loss is: [0.00041134]
# epoch: 87, iter: 20, loss is: [0.00101153]
# epoch: 87, iter: 40, loss is: [0.00097981]
# epoch: 88, iter: 0, loss is: [0.00151369]
# epoch: 88, iter: 20, loss is: [0.00111297]
# epoch: 88, iter: 40, loss is: [0.00284785]
# epoch: 89, iter: 0, loss is: [0.00162019]
# epoch: 89, iter: 20, loss is: [0.00118696]
# epoch: 89, iter: 40, loss is: [0.00022578]
# epoch: 90, iter: 0, loss is: [0.00052942]
# epoch: 90, iter: 20, loss is: [0.00161328]
# epoch: 90, iter: 40, loss is: [0.00148473]
# epoch: 91, iter: 0, loss is: [0.0004762]
# epoch: 91, iter: 20, loss is: [0.00173442]
# epoch: 91, iter: 40, loss is: [0.0007046]
# epoch: 92, iter: 0, loss is: [0.00199137]
# epoch: 92, iter: 20, loss is: [0.00296046]
# epoch: 92, iter: 40, loss is: [0.00172074]
# epoch: 93, iter: 0, loss is: [0.00334819]
# epoch: 93, iter: 20, loss is: [0.00399176]
# epoch: 93, iter: 40, loss is: [0.00067012]
# epoch: 94, iter: 0, loss is: [0.00049065]
# epoch: 94, iter: 20, loss is: [0.00097528]
# epoch: 94, iter: 40, loss is: [0.00216689]
# epoch: 95, iter: 0, loss is: [0.00129059]
# epoch: 95, iter: 20, loss is: [0.00296062]
# epoch: 95, iter: 40, loss is: [0.00079154]
# epoch: 96, iter: 0, loss is: [0.00071171]
# epoch: 96, iter: 20, loss is: [0.00210437]
# epoch: 96, iter: 40, loss is: [0.00704368]
# epoch: 97, iter: 0, loss is: [0.00409173]
# epoch: 97, iter: 20, loss is: [0.00150416]
# epoch: 97, iter: 40, loss is: [0.00190002]
# epoch: 98, iter: 0, loss is: [0.00127814]
# epoch: 98, iter: 20, loss is: [0.00095968]
# epoch: 98, iter: 40, loss is: [0.00145799]
# epoch: 99, iter: 0, loss is: [0.00161766]
# epoch: 99, iter: 20, loss is: [0.00233247]
# epoch: 99, iter: 40, loss is: [0.00187171]
# epoch: 100, iter: 0, loss is: [0.00179411]
# epoch: 100, iter: 20, loss is: [0.00070021]
# epoch: 100, iter: 40, loss is: [0.00169548]
# 模型保存成功，模型参数保存在LR_model.pdparams中
# Inference result is [[19.98059]], the corresponding label is 13.5
