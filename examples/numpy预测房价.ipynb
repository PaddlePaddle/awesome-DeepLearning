# %%
# 查看当前挂载的数据集目录, 该目录下的变更重启环境后会自动还原
# View dataset directory. 
# This directory will be recovered automatically after resetting environment. 
# !ls /home/aistudio/data

# %%
# 查看工作区文件, 该目录下的变更将会持久保存. 请及时清理不必要的文件, 避免加载过慢.
# View personal work directory. 
# All changes under this directory will be kept even after reset. 
# Please clean unnecessary files in time to speed up environment loading. 
# !ls /home/aistudio/work

# %%
# 如果需要进行持久化安装, 需要使用持久化路径, 如下方代码示例:
# If a persistence installation is required, 
# you need to use the persistence path as the following: 
# !mkdir /home/aistudio/external-libraries
# !pip install beautifulsoup4 -t /home/aistudio/external-libraries

# %%
# 同时添加如下代码, 这样每次环境(kernel)启动的时候只要运行下方代码即可: 
# Also add the following code, 
# so that every time the environment (kernel) starts, 
# just run the following code: 
import sys 
import numpy as np
import matplotlib.pyplot as plt


def load_data():
    # 1.从文件导入数据
    datafile = '/home/aistudio/data/data99050/housing.data'
    data = np.fromfile(datafile, sep=' ')

    # 每条数据包括14项，其中前面13项是影响因素，第14项是相应的房屋价格中位数
    feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', \
                     'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
    feature_num = len(feature_names)

    # 2.将原始数据进行Reshape，变成[N, 14]这样的形状
    data = data.reshape([data.shape[0] // feature_num, feature_num])

    # 3.将原数据集拆分成训练集和测试集
    # 这里使用80%的数据做训练，20%的数据做测试
    # 测试集和训练集必须是没有交集的
    ratio = 0.8
    offset = int(data.shape[0] * ratio)
    training_data = data[:offset]

    # 计算train数据集的最大值，最小值，平均值
    maximums, minimums, avgs = training_data.max(axis=0), training_data.min(axis=0), \
                               training_data.sum(axis=0) / training_data.shape[0]

    # 4.对数据进行归一化处理
    for i in range(feature_num):
        # print(maximums[i], minimums[i], avgs[i])
        data[:, i] = (data[:, i] - avgs[i]) / (maximums[i] - minimums[i])

    # 训练集和测试集的划分比例
    training_data = data[:offset]
    test_data = data[offset:]
    return training_data, test_data


class Network(object):
    def __init__(self, num_of_weights):
        # 随机产生w的初始值
        # 为了保持程序每次运行结果的一致性，此处设置固定的随机数种子
        # np.random.seed(0)
        self.w = np.random.randn(num_of_weights, 1)
        self.b = 0.

    def forward(self, x):
        z = np.dot(x, self.w) + self.b
        return z

    def loss(self, z, y):
        error = z - y
        num_samples = error.shape[0]
        cost = error * error
        cost = np.sum(cost) / num_samples
        return cost

    def gradient(self, x, y):
        z = self.forward(x)
        N = x.shape[0]
        gradient_w = 1. / N * np.sum((z - y) * x, axis=0)
        gradient_w = gradient_w[:, np.newaxis]
        gradient_b = 1. / N * np.sum(z - y)
        return gradient_w, gradient_b

    def update(self, gradient_w, gradient_b, eta=0.01):
        self.w = self.w - eta * gradient_w
        self.b = self.b - eta * gradient_b

    def train(self, training_data, num_epoches, batch_size=10, eta=0.01):
        n = len(training_data)
        losses = []
        for epoch_id in range(num_epoches):
            # 在每轮迭代开始之前，将训练数据的顺序随机的打乱，
            # 然后再按每次取batch_size条数据的方式取出
            np.random.shuffle(training_data)
            # 将训练数据进行拆分，每个mini_batch包含batch_size条的数据
            mini_batches = [training_data[k:k + batch_size] for k in range(0, n, batch_size)]
            for iter_id, mini_batch in enumerate(mini_batches):
                # print(self.w.shape)
                # print(self.b)
                x = mini_batch[:, :-1]
                y = mini_batch[:, -1:]
                a = self.forward(x)
                loss = self.loss(a, y)
                gradient_w, gradient_b = self.gradient(x, y)
                self.update(gradient_w, gradient_b, eta)
                losses.append(loss)
                print('Epoch {:3d} / iter {:3d}, loss = {:.4f}'.
                      format(epoch_id, iter_id, loss))

        return losses


# 获取数据
train_data, test_data = load_data()

# 创建网络
net = Network(13)
# 启动训练
losses = net.train(train_data, num_epoches=50, batch_size=100, eta=0.1)

# 画出损失函数的变化趋势
plot_x = np.arange(len(losses))
plot_y = np.array(losses)
plt.plot(plot_x, plot_y)
plt.show()
# Out:
# Epoch   0 / iter   0, loss = 0.7753
# Epoch   0 / iter   1, loss = 0.6803
# Epoch   0 / iter   2, loss = 0.7903
# Epoch   0 / iter   3, loss = 0.5474
# Epoch   0 / iter   4, loss = 0.4389
# Epoch   1 / iter   0, loss = 0.6400
# Epoch   1 / iter   1, loss = 0.7565
# Epoch   1 / iter   2, loss = 0.5445
# Epoch   1 / iter   3, loss = 0.5611
# Epoch   1 / iter   4, loss = 0.4015
# Epoch   2 / iter   0, loss = 0.6299
# Epoch   2 / iter   1, loss = 0.4687
# Epoch   2 / iter   2, loss = 0.5850
# Epoch   2 / iter   3, loss = 0.6401
# Epoch   2 / iter   4, loss = 0.3508
# Epoch   3 / iter   0, loss = 0.4574
# Epoch   3 / iter   1, loss = 0.7227
# Epoch   3 / iter   2, loss = 0.4611
# Epoch   3 / iter   3, loss = 0.4398
# Epoch   3 / iter   4, loss = 0.7012
# Epoch   4 / iter   0, loss = 0.4182
# Epoch   4 / iter   1, loss = 0.5507
# Epoch   4 / iter   2, loss = 0.3490
# Epoch   4 / iter   3, loss = 0.5449
# Epoch   4 / iter   4, loss = 0.6091
# Epoch   5 / iter   0, loss = 0.5610
# Epoch   5 / iter   1, loss = 0.3946
# Epoch   5 / iter   2, loss = 0.3458
# Epoch   5 / iter   3, loss = 0.3927
# Epoch   5 / iter   4, loss = 0.2885
# Epoch   6 / iter   0, loss = 0.3409
# Epoch   6 / iter   1, loss = 0.3601
# Epoch   6 / iter   2, loss = 0.4214
# Epoch   6 / iter   3, loss = 0.4453
# Epoch   6 / iter   4, loss = 0.6989
# Epoch   7 / iter   0, loss = 0.3514
# Epoch   7 / iter   1, loss = 0.3995
# Epoch   7 / iter   2, loss = 0.3866
# Epoch   7 / iter   3, loss = 0.3101
# Epoch   7 / iter   4, loss = 0.1196
# Epoch   8 / iter   0, loss = 0.2804
# Epoch   8 / iter   1, loss = 0.3254
# Epoch   8 / iter   2, loss = 0.3983
# Epoch   8 / iter   3, loss = 0.3436
# Epoch   8 / iter   4, loss = 0.2468
# Epoch   9 / iter   0, loss = 0.3415
# Epoch   9 / iter   1, loss = 0.3165
# Epoch   9 / iter   2, loss = 0.3155
# Epoch   9 / iter   3, loss = 0.2683
# Epoch   9 / iter   4, loss = 0.4909
# Epoch  10 / iter   0, loss = 0.3367
# Epoch  10 / iter   1, loss = 0.2777
# Epoch  10 / iter   2, loss = 0.2264
# Epoch  10 / iter   3, loss = 0.3245
# Epoch  10 / iter   4, loss = 0.1047
# Epoch  11 / iter   0, loss = 0.3017
# Epoch  11 / iter   1, loss = 0.2983
# Epoch  11 / iter   2, loss = 0.2833
# Epoch  11 / iter   3, loss = 0.2150
# Epoch  11 / iter   4, loss = 0.1157
# Epoch  12 / iter   0, loss = 0.2497
# Epoch  12 / iter   1, loss = 0.2807
# Epoch  12 / iter   2, loss = 0.2650
# Epoch  12 / iter   3, loss = 0.2375
# Epoch  12 / iter   4, loss = 0.1437
# Epoch  13 / iter   0, loss = 0.2113
# Epoch  13 / iter   1, loss = 0.2285
# Epoch  13 / iter   2, loss = 0.2711
# Epoch  13 / iter   3, loss = 0.2572
# Epoch  13 / iter   4, loss = 0.2712
# Epoch  14 / iter   0, loss = 0.2549
# Epoch  14 / iter   1, loss = 0.2292
# Epoch  14 / iter   2, loss = 0.1898
# Epoch  14 / iter   3, loss = 0.2598
# Epoch  14 / iter   4, loss = 0.0604
# Epoch  15 / iter   0, loss = 0.2255
# Epoch  15 / iter   1, loss = 0.2482
# Epoch  15 / iter   2, loss = 0.1895
# Epoch  15 / iter   3, loss = 0.2245
# Epoch  15 / iter   4, loss = 0.0939
# Epoch  16 / iter   0, loss = 0.2437
# Epoch  16 / iter   1, loss = 0.2059
# Epoch  16 / iter   2, loss = 0.1951
# Epoch  16 / iter   3, loss = 0.1910
# Epoch  16 / iter   4, loss = 0.2054
# Epoch  17 / iter   0, loss = 0.2162
# Epoch  17 / iter   1, loss = 0.1656
# Epoch  17 / iter   2, loss = 0.2310
# Epoch  17 / iter   3, loss = 0.1822
# Epoch  17 / iter   4, loss = 0.1450
# Epoch  18 / iter   0, loss = 0.2247
# Epoch  18 / iter   1, loss = 0.1585
# Epoch  18 / iter   2, loss = 0.1792
# Epoch  18 / iter   3, loss = 0.2001
# Epoch  18 / iter   4, loss = 0.0222
# Epoch  19 / iter   0, loss = 0.1370
# Epoch  19 / iter   1, loss = 0.1702
# Epoch  19 / iter   2, loss = 0.2100
# Epoch  19 / iter   3, loss = 0.2040
# Epoch  19 / iter   4, loss = 0.1528
# Epoch  20 / iter   0, loss = 0.1655
# Epoch  20 / iter   1, loss = 0.1754
# Epoch  20 / iter   2, loss = 0.1739
# Epoch  20 / iter   3, loss = 0.1653
# Epoch  20 / iter   4, loss = 0.1894
# Epoch  21 / iter   0, loss = 0.2160
# Epoch  21 / iter   1, loss = 0.1327
# Epoch  21 / iter   2, loss = 0.1486
# Epoch  21 / iter   3, loss = 0.1518
# Epoch  21 / iter   4, loss = 0.2430
# Epoch  22 / iter   0, loss = 0.1519
# Epoch  22 / iter   1, loss = 0.1647
# Epoch  22 / iter   2, loss = 0.1222
# Epoch  22 / iter   3, loss = 0.1768
# Epoch  22 / iter   4, loss = 0.1330
# Epoch  23 / iter   0, loss = 0.1530
# Epoch  23 / iter   1, loss = 0.1538
# Epoch  23 / iter   2, loss = 0.1138
# Epoch  23 / iter   3, loss = 0.1727
# Epoch  23 / iter   4, loss = 0.1401
# Epoch  24 / iter   0, loss = 0.1398
# Epoch  24 / iter   1, loss = 0.1440
# Epoch  24 / iter   2, loss = 0.1361
# Epoch  24 / iter   3, loss = 0.1496
# Epoch  24 / iter   4, loss = 0.0713
# Epoch  25 / iter   0, loss = 0.1524
# Epoch  25 / iter   1, loss = 0.1339
# Epoch  25 / iter   2, loss = 0.1182
# Epoch  25 / iter   3, loss = 0.1404
# Epoch  25 / iter   4, loss = 0.0637
# Epoch  26 / iter   0, loss = 0.1004
# Epoch  26 / iter   1, loss = 0.1309
# Epoch  26 / iter   2, loss = 0.1652
# Epoch  26 / iter   3, loss = 0.1306
# Epoch  26 / iter   4, loss = 0.0411
# Epoch  27 / iter   0, loss = 0.1199
# Epoch  27 / iter   1, loss = 0.1358
# Epoch  27 / iter   2, loss = 0.1234
# Epoch  27 / iter   3, loss = 0.1280
# Epoch  27 / iter   4, loss = 0.0662
# Epoch  28 / iter   0, loss = 0.1103
# Epoch  28 / iter   1, loss = 0.1460
# Epoch  28 / iter   2, loss = 0.1140
# Epoch  28 / iter   3, loss = 0.1193
# Epoch  28 / iter   4, loss = 0.0678
# Epoch  29 / iter   0, loss = 0.1469
# Epoch  29 / iter   1, loss = 0.1052
# Epoch  29 / iter   2, loss = 0.1312
# Epoch  29 / iter   3, loss = 0.0861
# Epoch  29 / iter   4, loss = 0.1609
# Epoch  30 / iter   0, loss = 0.1232
# Epoch  30 / iter   1, loss = 0.1077
# Epoch  30 / iter   2, loss = 0.1000
# Epoch  30 / iter   3, loss = 0.1244
# Epoch  30 / iter   4, loss = 0.0413
# Epoch  31 / iter   0, loss = 0.0922
# Epoch  31 / iter   1, loss = 0.0974
# Epoch  31 / iter   2, loss = 0.1026
# Epoch  31 / iter   3, loss = 0.1403
# Epoch  31 / iter   4, loss = 0.2241
# Epoch  32 / iter   0, loss = 0.0969
# Epoch  32 / iter   1, loss = 0.0938
# Epoch  32 / iter   2, loss = 0.0955
# Epoch  32 / iter   3, loss = 0.1351
# Epoch  32 / iter   4, loss = 0.0240
# Epoch  33 / iter   0, loss = 0.1123
# Epoch  33 / iter   1, loss = 0.0909
# Epoch  33 / iter   2, loss = 0.1011
# Epoch  33 / iter   3, loss = 0.1044
# Epoch  33 / iter   4, loss = 0.0497
# Epoch  34 / iter   0, loss = 0.1058
# Epoch  34 / iter   1, loss = 0.0867
# Epoch  34 / iter   2, loss = 0.1155
# Epoch  34 / iter   3, loss = 0.0885
# Epoch  34 / iter   4, loss = 0.1033
# Epoch  35 / iter   0, loss = 0.0997
# Epoch  35 / iter   1, loss = 0.1088
# Epoch  35 / iter   2, loss = 0.0864
# Epoch  35 / iter   3, loss = 0.0899
# Epoch  35 / iter   4, loss = 0.1752
# Epoch  36 / iter   0, loss = 0.0653
# Epoch  36 / iter   1, loss = 0.1290
# Epoch  36 / iter   2, loss = 0.0847
# Epoch  36 / iter   3, loss = 0.0963
# Epoch  36 / iter   4, loss = 0.0777
# Epoch  37 / iter   0, loss = 0.0646
# Epoch  37 / iter   1, loss = 0.0898
# Epoch  37 / iter   2, loss = 0.0806
# Epoch  37 / iter   3, loss = 0.1295
# Epoch  37 / iter   4, loss = 0.0886
# Epoch  38 / iter   0, loss = 0.0964
# Epoch  38 / iter   1, loss = 0.0684
# Epoch  38 / iter   2, loss = 0.0954
# Epoch  38 / iter   3, loss = 0.0946
# Epoch  38 / iter   4, loss = 0.0434
# Epoch  39 / iter   0, loss = 0.1298
# Epoch  39 / iter   1, loss = 0.0706
# Epoch  39 / iter   2, loss = 0.0721
# Epoch  39 / iter   3, loss = 0.0726
# Epoch  39 / iter   4, loss = 0.0888
# Epoch  40 / iter   0, loss = 0.0767
# Epoch  40 / iter   1, loss = 0.0923
# Epoch  40 / iter   2, loss = 0.0823
# Epoch  40 / iter   3, loss = 0.0857
# Epoch  40 / iter   4, loss = 0.0770
# Epoch  41 / iter   0, loss = 0.0918
# Epoch  41 / iter   1, loss = 0.0862
# Epoch  41 / iter   2, loss = 0.0695
# Epoch  41 / iter   3, loss = 0.0817
# Epoch  41 / iter   4, loss = 0.0700
# Epoch  42 / iter   0, loss = 0.0917
# Epoch  42 / iter   1, loss = 0.0679
# Epoch  42 / iter   2, loss = 0.0752
# Epoch  42 / iter   3, loss = 0.0840
# Epoch  42 / iter   4, loss = 0.1032
# Epoch  43 / iter   0, loss = 0.0767
# Epoch  43 / iter   1, loss = 0.0847
# Epoch  43 / iter   2, loss = 0.0740
# Epoch  43 / iter   3, loss = 0.0780
# Epoch  43 / iter   4, loss = 0.0242
# Epoch  44 / iter   0, loss = 0.0881
# Epoch  44 / iter   1, loss = 0.0835
# Epoch  44 / iter   2, loss = 0.0788
# Epoch  44 / iter   3, loss = 0.0570
# Epoch  44 / iter   4, loss = 0.0390
# Epoch  45 / iter   0, loss = 0.0876
# Epoch  45 / iter   1, loss = 0.0760
# Epoch  45 / iter   2, loss = 0.0563
# Epoch  45 / iter   3, loss = 0.0814
# Epoch  45 / iter   4, loss = 0.0285
# Epoch  46 / iter   0, loss = 0.0787
# Epoch  46 / iter   1, loss = 0.0718
# Epoch  46 / iter   2, loss = 0.0628
# Epoch  46 / iter   3, loss = 0.0763
# Epoch  46 / iter   4, loss = 0.1796
# Epoch  47 / iter   0, loss = 0.0691
# Epoch  47 / iter   1, loss = 0.0842
# Epoch  47 / iter   2, loss = 0.0703
# Epoch  47 / iter   3, loss = 0.0670
# Epoch  47 / iter   4, loss = 0.0320
# Epoch  48 / iter   0, loss = 0.0628
# Epoch  48 / iter   1, loss = 0.0630
# Epoch  48 / iter   2, loss = 0.0814
# Epoch  48 / iter   3, loss = 0.0769
# Epoch  48 / iter   4, loss = 0.0175
# Epoch  49 / iter   0, loss = 0.0817
# Epoch  49 / iter   1, loss = 0.0592
# Epoch  49 / iter   2, loss = 0.0706
# Epoch  49 / iter   3, loss = 0.0660
# Epoch  49 / iter   4, loss = 0.0872

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
